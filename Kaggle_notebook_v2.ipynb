# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
"""
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
"""

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ae-mehdi/ae_Mehdi.pt
# /kaggle/input/dlmi-challenge/clinical_annotation.csv
# /kaggle/input/dlmi-challenge/trainset/trainset/trainset_true.csv
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000050.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000081.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000091.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000075.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000096.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000076.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000056.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000077.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000084.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000064.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000070.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000085.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000088.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000093.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000083.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000051.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000101.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000095.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000086.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000068.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000061.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000066.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000104.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000072.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000063.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000052.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000080.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000097.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000100.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000065.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000054.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000087.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000082.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000098.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000067.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000071.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000105.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000073.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000094.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000060.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000079.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000103.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000106.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000074.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000057.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000078.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000053.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000069.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000102.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000062.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000089.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000090.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000049.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000099.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000092.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000055.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000059.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000058.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000107.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P135/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P62/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000050.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000056.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000064.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000051.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000061.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000063.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000052.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000065.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000054.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000060.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000057.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000053.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000062.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000049.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000055.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000059.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000058.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P201/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/45.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/56.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/20.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/58.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/6.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/76.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/71.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/5.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/8.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/67.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/30.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/38.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/42.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/33.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/10.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/54.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/0.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/62.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/35.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/61.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/59.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/73.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/41.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/60.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/57.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/9.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/37.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/1.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/69.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/75.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/46.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/44.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/65.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/50.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/29.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/79.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/16.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/55.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/23.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/7.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/77.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/80.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/28.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/22.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/40.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/48.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/24.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/64.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/31.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/43.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/13.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/74.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/68.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/53.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/72.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/32.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/17.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/26.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/39.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/15.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/12.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/11.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/70.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/34.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/27.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/51.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/52.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/21.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/4.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/3.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/36.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/63.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/19.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/47.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/14.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/18.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/78.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/49.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/66.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/2.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/Fake_P0/25.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000050.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000051.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000049.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P101/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P50/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000049.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P34/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P17/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P51/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000050.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000081.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000091.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000075.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000096.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000076.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000056.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000077.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000084.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000064.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000070.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000085.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000088.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000093.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000083.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000051.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000101.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000095.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000086.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000068.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000061.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000066.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000072.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000063.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000052.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000080.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000097.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000100.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000065.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000054.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000087.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000082.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000098.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000067.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000071.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000073.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000094.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000060.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000079.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000074.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000057.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000078.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000053.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000069.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000062.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000089.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000090.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000049.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000099.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000092.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000055.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000059.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000058.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P189/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P116/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P54/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P146/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000040.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000021.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000015.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000029.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000018.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000031.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000028.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000023.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000037.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000025.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000047.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000004.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000016.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000032.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000009.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000003.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000008.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000034.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000035.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000019.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000002.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000001.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000045.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000005.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000014.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000011.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000033.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000000.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000010.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000039.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000046.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000022.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000013.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000024.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000020.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000006.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000012.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000043.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000027.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000041.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000036.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000044.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000007.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000042.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000017.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000030.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000048.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P36/000026.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P190/000050.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P190/000111.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P190/000038.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P190/000081.jpg
# /kaggle/input/dlmi-challenge/trainset/trainset/P190/000091.jpg
# ...
# /kaggle/input/dlmi-challenge/testset/testset/P4/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P4/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P4/000048.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P4/000026.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000021.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000015.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000029.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000018.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000031.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000028.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000023.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000025.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000004.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000016.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000032.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000009.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000003.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000008.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000019.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000002.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000001.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000005.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000014.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000011.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000000.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000010.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000022.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000013.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000024.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000020.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000006.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000012.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000027.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000007.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P148/000026.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000050.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000038.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000040.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000021.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000015.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000029.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000018.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000031.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000028.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000051.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000023.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000037.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000025.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000047.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000004.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000016.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000032.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000009.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000003.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000008.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000034.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000035.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000019.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000002.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000052.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000001.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000045.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000005.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000014.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000054.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000011.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000033.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000000.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000010.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000039.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000046.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000022.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000013.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000053.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000024.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000020.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000006.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000012.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000043.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000027.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000041.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000036.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000044.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000007.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000049.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000042.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000048.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P24/000026.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000021.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000015.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000029.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000018.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000031.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000028.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000023.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000025.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000004.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000016.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000032.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000009.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000003.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000008.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000034.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000019.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000002.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000001.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000005.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000014.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000011.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000033.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000000.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000010.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000022.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000013.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000024.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000020.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000006.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000012.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000027.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000007.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P86/000026.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000050.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000038.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000081.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000040.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000021.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000015.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000075.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000029.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000076.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000056.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000077.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000084.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000018.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000031.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000064.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000070.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000028.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000083.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000051.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000023.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000037.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000025.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000068.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000047.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000061.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000004.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000016.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000066.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000032.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000009.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000003.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000072.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000008.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000034.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000063.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000035.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000019.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000002.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000052.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000080.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000001.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000045.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000005.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000065.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000014.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000054.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000082.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000011.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000067.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000071.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000073.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000033.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000060.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000000.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000010.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000079.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000039.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000074.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000046.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000022.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000057.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000013.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000078.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000053.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000024.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000020.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000006.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000012.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000043.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000069.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000027.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000041.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000036.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000062.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000044.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000007.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000049.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000042.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000055.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000048.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000059.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000058.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P69/000026.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000050.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000038.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000040.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000021.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000015.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000029.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000018.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000031.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000028.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000051.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000023.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000037.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000025.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000047.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000004.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000016.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000032.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000009.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000003.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000008.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000034.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000035.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000019.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000002.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000052.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000001.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000045.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000005.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000014.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000011.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000033.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000000.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000010.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000039.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000046.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000022.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000013.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000024.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000020.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000006.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000012.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000043.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000027.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000041.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000036.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000044.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000007.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000049.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000042.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000017.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000030.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000048.jpg
# /kaggle/input/dlmi-challenge/testset/testset/P188/000026.jpg

# %%
import os 
import numpy as np
import pandas as pd 
import warnings
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score
from torch.utils.data import DataLoader, random_split
from torch.utils.data import Dataset
from PIL import Image

# %%
# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # PATHS

# %%
cwd = os.getcwd()
trainset_path = "/kaggle/input/dlmi-challenge/trainset/trainset"
testset_path = "/kaggle/input/dlmi-challenge/testset/testset"
ae_Mehdi = "/kaggle/input/ae-mehdi/ae_Mehdi.pt"

ae_training = False
submission = False

# %% [markdown]
# # TOOLS - Custom classes and functions

# %% [markdown]
# ## Data loaders

# %%
class PatientDataset(Dataset):
    def __init__(self, root_dir, annotation: pd.DataFrame, patients: list, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.patients = patients
        self.df = annotation

    def __len__(self):
        return len(self.patients)

    def __getitem__(self, idx):
        patient_folder = os.path.join(self.root_dir, self.patients[idx])
        images = []
        for filename in os.listdir(patient_folder):
            image_path = os.path.join(patient_folder, filename)
            image = Image.open(image_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            images.append(image)

        # get label 
        label = self.df[self.df.index == self.patients[idx]].LABEL
        label_tensor = torch.tensor([label], dtype=torch.float32)

        # get features 
        features = self.df[self.df.index == self.patients[idx]].drop("LABEL", axis=1).to_numpy()
        features_tensor = torch.tensor([features], dtype=torch.float32)
    
        return torch.stack(images), features_tensor, label_tensor, self.patients[idx]

# %%
class ImageLevelDataset(Dataset):
    def __init__(self, root_dir, list_images, labels, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.list_img = list_images
        self.labels = labels

    def __len__(self):
        return len(self.list_img)

    def __getitem__(self, idx):
        img_path, patient = self.list_img[idx]

        # get image and label
        label = self.labels[patient]
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:  # transform image
                image = self.transform(image)

        # transfrom label to right format
        label_tensor = torch.tensor([label], dtype=torch.float32)
        return image, label_tensor

# %% [markdown]
# ## Models

# %% [markdown]
# ### Features extractor

# %%
class Autoencoder(nn.Module):
    def __init__(self, latent_size=128):
        super(Autoencoder, self).__init__()

        # define latent size
        self.latent_size = latent_size

        # define encoder 
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # close to latent space
        self.fc_encoder = nn.Linear(256 * 28 * 28, latent_size)
        self.fc_decoder = nn.Linear(latent_size, 256 * 28 * 28)

        # decoder architecture
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1,output_padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 3, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.view(x.size(0), -1)
        x = self.fc_encoder(x)
        x = self.fc_decoder(x)
        x = x.view(x.size(0), 256, 28, 28)
        x = self.decoder(x)
        return x

    def embedding(self, x):
        x = self.encoder(x)
        x = x.view(x.size(0), -1)
        x = self.fc_encoder(x)
        return x

# %% [markdown]
# ### Classifier

# %%
class DeepSets(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int):
        """
        Initialization of the deep set model. 

        :params input_dim: int
            Dimension of each element of the input. 
        :params hidden_dim: int 
            Dimension of hidden layers. 
        :parasm output_dim: int 
            Dimensionality of output
        """
        super(DeepSets, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        
        # Shared layers
        self.shared_layers = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),  
            nn.Sigmoid()
        )
        
        # Permutation-invariant layer
        self.invariant_layer = nn.Sequential(
            nn.Linear(hidden_dim+3, output_dim), 
            nn.Sigmoid()
        )

    def forward(self, x):
        """
        Foward function of deep set model that given images features and 
        tabular data return a prediction.

        :params x: tuple
            Tuples containing one 2d tensor and one 1d tensor.

        :return one value 
        """
        # seperate img features and tabular data
        img_features, tabular = x
        
        # Apply shared layers to each element of the set
        output = self.shared_layers(img_features)
        
        # Permutation-invariant aggregation
        v, _ = torch.max(output, dim=0)
        
        # concatenate tabular data and feature from bag of images
        conc = torch.concat([v, tabular], dim=-1)
        
        # Apply permutation-invariant layer
        output = self.invariant_layer(conc)
        
        return output

# %% [markdown]
# # Introduction

# %%
annotation_file = os.path.join("/kaggle/input/dlmi-challenge/clinical_annotation.csv")
df_ann = pd.read_csv(annotation_file)
df_ann.drop("Unnamed: 0", axis=1, inplace=True)

### RAPID PREPROCESSING

# compute age 
def compute_age(x):
    year = int(x[-4:])
    return 2024 - year
    
df_ann["age"] = df_ann.DOB.apply(compute_age)
df_ann.drop("DOB", axis=1, inplace=True)

#encode gender
df_ann["GENDER"] = df_ann["GENDER"].replace('f', "F")
label_encoder = LabelEncoder()
df_ann['GENDER'] = label_encoder.fit_transform(df_ann['GENDER'])

df_ann.set_index("ID", inplace=True)

# %%
df_ann.head()
# Out:
#       LABEL  GENDER  LYMPH_COUNT  age
# ID
# P26       1       1         11.2   91
# P183      1       1         12.8   82
# P89       1       1          9.6   89
# P123      1       1        122.6   93
# P61       1       0         11.6   93

# %%
sub_patients = list(df_ann.loc[df_ann.LABEL==-1].index)

# %% [markdown]
# ## Train-test split

# %% [markdown]
# Isolate as soon as possible our future test data. As the dataset is imbalanced (70% positive), we make a stratifiy train-test split:
# $ 14 = 20 \times 0.7 $

# %%
test_patients = list(df_ann[df_ann.LABEL==0].sample(14).index)
test_patients += list(df_ann[df_ann.LABEL==1].sample(20).index)
print("Test size: ", len(test_patients))
print("Test patients: ", test_patients)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test_patients = list(df_ann[df_ann.LABEL==0].sample(14).index)
#       2 test_patients += list(df_ann[df_ann.LABEL==1].sample(20).index)
#       3 print("Test size: ", len(test_patients))
#
# NameError: name 'df_ann' is not defined

# %% [markdown]
# Define submission, train and test set

# %%
sub_df = df_ann[df_ann.index.isin(sub_patients)]  # submission patients
test_df = df_ann[df_ann.index.isin(test_patients)]  # test patients

# train patients are the others
train_patients = list(set(df_ann.index) - set(test_patients) - set(sub_patients))
train_df = df_ann[df_ann.index.isin(train_patients)]

# %% [markdown]
# # Feature extraction with Auto-encoder

# %% [markdown]
# ## Data loader

# %%
# preparation of data loader
labels = train_df.LABEL.to_dict()
transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])

list_images = []
for pat in train_patients:
    for img in os.listdir(os.path.join(trainset_path, pat)):
        list_images.append((os.path.join(trainset_path, pat, img), pat))
        
print(list_images[0])
# Out:
# ('/kaggle/input/dlmi-challenge/trainset/trainset/P1/000050.jpg', 'P1')

# %%
dataset = ImageLevelDataset("./data/trainset/", list_images, labels, transform) 
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ## Training

# %%
# Check if GPU is available and set device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
if ae_training:

    # Initialize the model
    model = Autoencoder(latent_size=128).to(device)

    # Define loss function (here MSE)
    criterion = torch.nn.MSELoss()

    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Train the model
    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for images, _ in train_loader:
            optimizer.zero_grad()
            images = images.to(device)
            outputs = model(images)
            loss = criterion(outputs, images)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}")

else:
    
    model = Autoencoder(latent_size=128)
    model.load_state_dict(torch.load(ae_Mehdi, map_location=torch.device(device)))

# %%
if ae_training: 
    torch.save(model.state_dict(), 'ae_Mehdi.pt')

# %% [markdown]
# ## Test auto-encoder performance on test set

# %%
test_labels = test_df.LABEL.to_dict()
list_images_test = []
for pat in test_patients:
    for img in os.listdir(os.path.join(trainset_path, pat)):
        list_images_test.append((os.path.join(trainset_path, pat, img), pat))
        
print(list_images_test[:3])
# Out:
# [('/kaggle/input/dlmi-challenge/trainset/trainset/P64/000038.jpg', 'P64'), ('/kaggle/input/dlmi-challenge/trainset/trainset/P64/000040.jpg', 'P64'), ('/kaggle/input/dlmi-challenge/trainset/trainset/P64/000021.jpg', 'P64')]

# %%
test_ae_dataset = ImageLevelDataset("./data/trainset/", list_images_test, test_labels, transform) 
test_loader = DataLoader(test_ae_dataset, batch_size=32, shuffle=False)

mse_array = np.zeros(len(test_loader))
with torch.no_grad():
    i = 0
    nb_img = 0
    for images, labels in test_loader:
        nb_img += images.size(0)
        images = images.to(device)
        outputs = model(images)
        mse_ = (outputs - images) ** 2
        mse_array[i] = torch.sum(mse_)
        i += 1

total_nb_pixels = nb_img * 224 * 224
print(f"Test MSE: {np.sum(mse_array) / total_nb_pixels}%")
# Out:
# Test MSE: 8.338154958827155e-05%

# %% [markdown]
# # Classification using deep sets

# %%
dataset = PatientDataset(
    root_dir=trainset_path, 
    annotation=train_df,
    patients=train_patients, 
    transform=transform
    )
loader = DataLoader(dataset)

# %%
clf = DeepSets(
    input_dim=128,# size of embedding space
    hidden_dim=32, 
    output_dim=1
).to(device)
criterion = nn.BCELoss()  # Binary Cross Entropy Loss for binary classification
optimizer = torch.optim.Adam(clf.parameters(), lr=0.001)


num_epochs = 10
for epoch in range(num_epochs): 
    running_loss = 0.0
    
    for data in loader:
        img, tab, label, pat = data
        
        # process image
        img = torch.squeeze(img, dim=0).to(device)
        
        # rabular data
        tab = tab.squeeze().to(device)

        # label
        label = torch.squeeze(label, dim=(0, 1)).to(device)

        # patient
        patient = pat[0]
        
        # zero grad
        optimizer.zero_grad() 
        
        # input of deep sets
        features_img = model.embedding(img)

        clf_output = clf((features_img, tab))  
        loss = criterion(clf_output, label)
        loss.backward()  # Backward pass
        optimizer.step()  # Optimize
        
        # running loss update
        running_loss += loss.item()
        
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(test_loader)}")
# Out:
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:27: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /usr/local/src/pytorch/torch/csrc/utils/tensor_new.cpp:261.)
#   features_tensor = torch.tensor([features], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# Epoch 1/10, Loss: 3.9102158897720494
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# ...
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# Epoch 10/10, Loss: 0.6439445176998999

# %%
torch.save(clf.state_dict(), 'deepsets_model_max.pt')

# %% [markdown]
# # Test the model

# %%
dataset = PatientDataset(
    root_dir=trainset_path, 
    annotation=test_df,
    patients=test_patients, 
    transform=transform
    )
loader = DataLoader(dataset)

# %%
labels = np.zeros(len(loader))
pred = np.zeros(len(loader))

with torch.no_grad():
    i = 0
    for data in loader:
        img, tab, label, pat = data
        
        # process image
        img = torch.squeeze(img, dim=0).to(device)
        
        # rabular data
        tab = tab.squeeze().to(device)

        # label
        label = torch.squeeze(label, dim=(0, 1)).to(device)

        # patient
        patient = pat[0]
        
        # zero grad
        optimizer.zero_grad() 
        
        # input of deep sets
        features_img = model.embedding(img)

        clf_output = clf((features_img, tab))  

        labels[i] = label.detach().numpy()
        pred[i] = clf_output.detach().numpy()

# %% [markdown]
# Measure performance

# %%
# get actual pred 
actual_pred = np.where(pred >= 0.5, 1, 0)

# compute balance accuracy 
balanced_acc = balanced_accuracy_score(labels, actual_pred)

print("Balanced accuracy: ", balanced_acc)
# Out:
# Balanced accuracy:  0.8333333333333333

# %% [markdown]
# # For submission

# %%
if submission:
    # submission loader
    test_dataset = PatientDataset(
        root_dir=testset_path, 
        annotation=sub_df,
        patients=sub_patients, 
        transform=transform
        )
    sub_loader = DataLoader(test_dataset)

    # store results
    dico = {}
    with torch.no_grad():
        
        for data in sub_loader:
            img, tab, label, pat = data
            
            # process image
            img = torch.squeeze(img, dim=0).to(device)
            
            # rabular data
            tab = tab.squeeze().to(device)

            # label
            label = torch.squeeze(label, dim=(0, 1)).to(device)

            # patient
            patient = pat[0]
            
            # input of deep sets
            features_img = model.embedding(img)

            clf_output = clf((features_img, tab))  
            
            dico[patient] = clf_output.cpu().detach().numpy()
            
    print(dico)
# Out:
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)
# {'P71': array([0.76742834], dtype=float32), 'P16': array([0.9295041], dtype=float32), 'P114': array([0.9183822], dtype=float32), 'P170': array([0.8825037], dtype=float32), 'P98': array([0.44708008], dtype=float32), 'P69': array([0.31011942], dtype=float32), 'P92': array([0.96759844], dtype=float32), 'P132': array([0.89355636], dtype=float32), 'P81': array([0.9552589], dtype=float32), 'P73': array([0.9454633], dtype=float32), 'P143': array([0.97953206], dtype=float32), 'P175': array([0.807896], dtype=float32), 'P56': array([0.42450717], dtype=float32), 'P139': array([0.70481956], dtype=float32), 'P152': array([0.8599884], dtype=float32), 'P203': array([0.24738945], dtype=float32), 'P75': array([0.98958963], dtype=float32), 'P9': array([0.9241715], dtype=float32), 'P24': array([0.5495216], dtype=float32), 'P4': array([0.31027108], dtype=float32), 'P32': array([0.99986863], dtype=float32), 'P120': array([0.9405227], dtype=float32), 'P138': array([0.9384365], dtype=float32), 'P172': array([0.76754546], dtype=float32), 'P57': array([0.5699897], dtype=float32), 'P195': array([0.99993217], dtype=float32), 'P68': array([0.26180515], dtype=float32), 'P133': array([0.715724], dtype=float32), 'P14': array([0.91645], dtype=float32), 'P119': array([0.5745658], dtype=float32), 'P7': array([0.09088948], dtype=float32), 'P49': array([0.2768489], dtype=float32), 'P93': array([0.67849785], dtype=float32), 'P178': array([0.26766416], dtype=float32), 'P58': array([0.5336731], dtype=float32), 'P108': array([0.9174045], dtype=float32), 'P197': array([0.11343291], dtype=float32), 'P196': array([0.8011753], dtype=float32), 'P86': array([0.82361925], dtype=float32), 'P18': array([0.6339268], dtype=float32), 'P188': array([0.9015406], dtype=float32), 'P148': array([0.7644765], dtype=float32)}
# /tmp/ipykernel_34/1982661277.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label_tensor = torch.tensor([label], dtype=torch.float32)

# %%
if submission:
    final_df = pd.DataFrame()

    final_df["ID"] = dico.keys()
    final_df["clf_pred"] = dico.values()
    final_df["predicted"] = final_df.clf_pred.apply(lambda x: 1 if x >= 0.5 else 0)
    final_df.drop("clf_pred", axis=1, inplace=True)
    final_df.set_index("ID", inplace=True)

    final_df.head()
# Out:
#       predicted
# ID
# P71           1
# P16           1
# P114          1
# P170          1
# P98           0

# %%
if submission:
    final_df.to_csv("deepsets_max.csv")
